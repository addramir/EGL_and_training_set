# %%
# !gcloud auth application-default login
# Out:
# zsh:1: command not found: gcloud

# %%
import os

# Add the Google Cloud SDK to the PATH
os.environ['PATH'] += os.pathsep + '/opt/homebrew/bin/gcloud'

# %%
# !gcloud --version
# Out:
# zsh:1: command not found: gcloud

# %%
import os
print(os.environ['PATH'])
# Out:
# /Users/yt4/Library/Caches/pypoetry/virtualenvs/gentropy-krNFZEZg-py3.10/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/homebrew/bin/gcloud
